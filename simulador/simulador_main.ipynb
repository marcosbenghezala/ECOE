# %% [markdown]
# # Simulador ECOE - Universidad Miguel Hernández
#
# Ejecute la siguiente celda para iniciar el simulador.

# %%
# Clonar repositorio y configurar entorno
# !git clone https://github.com/usuario/ECOE.git
# %cd ECOE
# !pip install -r requirements.txt

from simulador.app import run_simulator
run_simulator()
